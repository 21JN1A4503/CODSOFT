# %% [markdown]
# <a href="https://colab.research.google.com/github/21JN1A4503/CODSOFT/blob/main/TASK_2_CREDIT_CARD_FRAUD_DETECTION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CREDIT CARD FRAUD DETECTION

# %% [markdown]
# It is used for detecting the frauds in credit cards.

# %%
# Importig the libraries

import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, recall_score , classification_report

# %%
# loding the dataset

cc_data= pd.read_csv('/content/creditcard.csv')

# %%
cc_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
cc_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3973 entries, 0 to 3972
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    3973 non-null   int64
#  1   V1      3973 non-null   float64
#  2   V2      3973 non-null   float64
#  3   V3      3973 non-null   float64
#  4   V4      3973 non-null   float64
#  5   V5      3973 non-null   float64
#  6   V6      3973 non-null   float64
#  7   V7      3973 non-null   float64
#  8   V8      3973 non-null   float64
#  9   V9      3973 non-null   float64
#  10  V10     3973 non-null   float64
#  11  V11     3973 non-null   float64
#  12  V12     3973 non-null   float64
#  13  V13     3973 non-null   float64
#  14  V14     3973 non-null   float64
#  15  V15     3973 non-null   float64
#  16  V16     3973 non-null   float64
#  17  V17     3973 non-null   float64
#  18  V18     3973 non-null   float64
#  19  V19     3973 non-null   float64
# ...

# %%
# Checking the missing values
cc_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
# distribution of legit transaction and fradulent transaction

cc_data['Class'].value_counts()
# 0---> normal transaction
# 1---> fradulent transaction
# Out:
# 0.0    3970
# 1.0       2
# Name: Class, dtype: int64

# %%
# separating the data

legit=cc_data[cc_data.Class==0]
fraud=cc_data[cc_data.Class==1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (3970, 31)
# (2, 31)

# %%
# Statstical info
legit.Amount.describe()
# Out:
# count    3970.000000
# mean       64.899597
# std       213.612570
# min         0.000000
# 25%         2.270000
# 50%        12.990000
# 75%        54.990000
# max      7712.430000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count      2.000000
# mean     264.500000
# std      374.059487
# min        0.000000
# 25%      132.250000
# 50%      264.500000
# 75%      396.750000
# max      529.000000
# Name: Amount, dtype: float64

# %%
# comparing the values

cc_data.groupby('Class').mean()
# Out:
#               Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    1638.828463 -0.332459  0.308935  0.837446  0.011432 -0.029468
# 1.0     439.000000 -2.677884 -0.602658 -0.260694  3.143275  0.418809
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.053530  0.147357 -0.071642  0.056211  ...  0.059567  0.010282
# 1.0   -1.245684 -1.105907  0.661932 -1.520521  ...  1.114625  0.589464
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.082957 -0.058743  0.029114  0.095244 -0.012637  0.044658  0.002668
# 1.0    0.200214  0.455377  0.013198  0.162159  0.016239  0.004186 -0.053756
#
#            Amount
# Class
# 0.0     64.899597
# 1.0    264.500000
#
# [2 rows x 30 columns]

# %%
# Under Sampling -- building a sample dataset containing similar distribution of normal transaction and fradulent transaction.

#number of fradulent transaction = 492


legit_sample=legit.sample(n=492)

# %%
# concatenating

new_data=pd.concat([legit_sample, fraud],axis=0)

# %%
new_data.tail() # checking bottem columns and rows
# Out:
#       Time        V1        V2        V3        V4        V5        V6  \
# 1602  1247  1.055550 -0.282119 -0.074789  0.251727  0.833534  2.307399
# 2655  2189  0.076641  0.840775  0.630554  0.433788  0.015145  0.348943
# 3272  2821 -0.977630 -1.625280  1.220974 -1.406443 -0.252722  0.798663
# 541    406 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623    472 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
#
#             V7        V8        V9  ...       V21       V22       V23  \
# 1602 -0.488179  0.699448  0.317465  ... -0.132353 -0.127154 -0.025559
# 2655 -0.587464 -1.402942 -0.331101  ...  1.316097 -1.191293  0.051294
# 3272 -0.390497  0.365535 -2.669198  ...  0.083660  0.233112  0.788879
# 541  -2.537387  1.391657 -2.770089  ...  0.517232 -0.035049 -0.465211
# 623   0.325574 -0.067794 -0.270953  ...  0.661696  0.435477  1.375966
#
#            V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_data['Class'].value_counts() # verifying cancatenated data
# Out:
# 0.0    492
# 1.0      2
# Name: Class, dtype: int64

# %%
new_data.groupby('Class').mean()
# Out:
#               Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    1665.138211 -0.331742  0.365609  0.803156 -0.072607 -0.023210
# 1.0     439.000000 -2.677884 -0.602658 -0.260694  3.143275  0.418809
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.053719  0.172724 -0.092068  0.091782  ...  0.048070  0.040179
# 1.0   -1.245684 -1.105907  0.661932 -1.520521  ...  1.114625  0.589464
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.101046 -0.056742  0.010573  0.118754  0.001494  0.020627  0.006877
# 1.0    0.200214  0.455377  0.013198  0.162159  0.016239  0.004186 -0.053756
#
#            Amount
# Class
# 0.0     60.109695
# 1.0    264.500000
#
# [2 rows x 30 columns]

# %%
# Spliting the data into Features and Targets

X=new_data.drop(columns='Class', axis=1)
Y=new_data['Class']

# %%
print(X)
# Out:
#       Time        V1        V2        V3        V4        V5        V6  \
# 3954  3579  0.729185 -1.482025 -0.284564 -0.237517 -0.979221 -0.458951
# 3754  3247  1.127323 -0.371934  0.484213  1.221465  0.097472  1.898781
# 11      10  0.384978  0.616109 -0.874300 -0.094019  2.924584  3.317027
# 1528  1196  1.363375 -0.614852  0.425789 -0.834445 -1.019101 -0.546028
# 2093  1613 -2.399271  2.184654  0.392056 -0.875031 -1.027723 -0.894161
# ...    ...       ...       ...       ...       ...       ...       ...
# 1602  1247  1.055550 -0.282119 -0.074789  0.251727  0.833534  2.307399
# 2655  2189  0.076641  0.840775  0.630554  0.433788  0.015145  0.348943
# 3272  2821 -0.977630 -1.625280  1.220974 -1.406443 -0.252722  0.798663
# 541    406 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623    472 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
#
#             V7        V8        V9  ...       V20       V21       V22  \
# ...

# %%
print(Y)
# Out:
# 3954    0.0
# 3754    0.0
# 11      0.0
# 1528    0.0
# 2093    0.0
#        ...
# 1602    0.0
# 2655    0.0
# 3272    0.0
# 541     1.0
# 623     1.0
# Name: Class, Length: 494, dtype: float64

# %%
# Split the data into train and test

X_train,X_test,Y_train,Y_test=train_test_split (X,Y, test_size=0.2, stratify=Y,random_state=2)

# %%
print(X.shape, X_train.shape,X_test.shape)
# Out:
# (494, 30) (395, 30) (99, 30)

# %%
# model trainging

model=LogisticRegression()

# %%
# training the model with training data

model.fit(X_train, Y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
# accuracy on training data

X_train_prediction=model.predict(X_train)
training_data_accuracy=accuracy_score(X_train_prediction,Y_train)

# %%
print('Accuracy on training data :',training_data_accuracy )
# Out:
# Accuracy on training data : 1.0

# %%
# accuracy on test data

X_test_prediction=model.predict(X_test)
test_data_accuracy=accuracy_score(X_test_prediction,Y_test)

# %%
print('Accuracy on test data :',test_data_accuracy)
# Out:
# Accuracy on test data : 1.0

# %%
print (classification_report(Y_test , model.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        99
#
#     accuracy                           1.00        99
#    macro avg       1.00      1.00      1.00        99
# weighted avg       1.00      1.00      1.00        99
